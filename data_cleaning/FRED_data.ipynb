# %%
import pandas as pd

# %%
df = pd.read_csv('../data/fred_data.csv')

# %%
df.head()
# Out:
#          DATE  A067RL1Q156SBEA  A067RL1Q156SBEA_CCA  A067RL1Q156SBEA_CCH  \
# 0  1947-01-01              NaN                  NaN                  NaN
# 1  1947-04-01             -3.8                  NaN                  NaN
# 2  1947-07-01             11.1                  NaN                  NaN
# 3  1947-10-01             -5.5                  NaN                  NaN
# 4  1948-01-01              7.7                  NaN                  NaN
#
#    A067RL1Q156SBEA_CH1  A067RL1Q156SBEA_CHG  A067RL1Q156SBEA_LOG  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                 14.9                  2.4
# 3                  NaN                -16.6                  NaN
# 4                  NaN                 13.2                  2.0
#
#    A067RL1Q156SBEA_PC1  A067RL1Q156SBEA_PCA  A067RL1Q156SBEA_PCH  ...  \
# 0                  NaN                  NaN                  NaN  ...
# 1                  NaN                  NaN                  NaN  ...
# 2                  NaN               7180.4               -392.1  ...
# 3                  NaN                -94.0               -149.5  ...
# 4                  NaN                284.2               -240.0  ...
#
#    PCEC_PCH  TDSP  TDSP_CCA  TDSP_CCH  TDSP_CH1  TDSP_CHG  TDSP_LOG  TDSP_PC1  \
# 0       NaN   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       2.5   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       2.2   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       2.5   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       1.6   NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    TDSP_PCA  TDSP_PCH
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 100 columns]

# %%
# Clean data
df_rename = df.rename({'DATE':'quarter'}, axis=1)
df_rename.head()
# Out:
#       quarter  A067RL1Q156SBEA  A067RL1Q156SBEA_CCA  A067RL1Q156SBEA_CCH  \
# 0  1947-01-01              NaN                  NaN                  NaN
# 1  1947-04-01             -3.8                  NaN                  NaN
# 2  1947-07-01             11.1                  NaN                  NaN
# 3  1947-10-01             -5.5                  NaN                  NaN
# 4  1948-01-01              7.7                  NaN                  NaN
#
#    A067RL1Q156SBEA_CH1  A067RL1Q156SBEA_CHG  A067RL1Q156SBEA_LOG  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                 14.9                  2.4
# 3                  NaN                -16.6                  NaN
# 4                  NaN                 13.2                  2.0
#
#    A067RL1Q156SBEA_PC1  A067RL1Q156SBEA_PCA  A067RL1Q156SBEA_PCH  ...  \
# 0                  NaN                  NaN                  NaN  ...
# 1                  NaN                  NaN                  NaN  ...
# 2                  NaN               7180.4               -392.1  ...
# 3                  NaN                -94.0               -149.5  ...
# 4                  NaN                284.2               -240.0  ...
#
#    PCEC_PCH  TDSP  TDSP_CCA  TDSP_CCH  TDSP_CH1  TDSP_CHG  TDSP_LOG  TDSP_PC1  \
# 0       NaN   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       2.5   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       2.2   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       2.5   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       1.6   NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    TDSP_PCA  TDSP_PCH
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 100 columns]

# %%
# Update values in 'quarter' column to have the format: YYYYQ1-4. Example: 1970Q1

def map_quarter(s):
    quarter = ''
    month = s.split('-')[1]
    year = s.split('-')[0]
    
    if month == '01':
        quarter = '1'
    elif month == '04':
        quarter = '2'
    elif month == '07':
        quarter = '3'
    elif month == '10':
        quarter = '4'
        
    x = year + 'Q' + quarter
    
    return x

df_rename['quarter'] = df_rename['quarter'].apply(map_quarter)
df_rename.head()
# Out:
#   quarter  A067RL1Q156SBEA  A067RL1Q156SBEA_CCA  A067RL1Q156SBEA_CCH  \
# 0  1947Q1              NaN                  NaN                  NaN
# 1  1947Q2             -3.8                  NaN                  NaN
# 2  1947Q3             11.1                  NaN                  NaN
# 3  1947Q4             -5.5                  NaN                  NaN
# 4  1948Q1              7.7                  NaN                  NaN
#
#    A067RL1Q156SBEA_CH1  A067RL1Q156SBEA_CHG  A067RL1Q156SBEA_LOG  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                 14.9                  2.4
# 3                  NaN                -16.6                  NaN
# 4                  NaN                 13.2                  2.0
#
#    A067RL1Q156SBEA_PC1  A067RL1Q156SBEA_PCA  A067RL1Q156SBEA_PCH  ...  \
# 0                  NaN                  NaN                  NaN  ...
# 1                  NaN                  NaN                  NaN  ...
# 2                  NaN               7180.4               -392.1  ...
# 3                  NaN                -94.0               -149.5  ...
# 4                  NaN                284.2               -240.0  ...
#
#    PCEC_PCH  TDSP  TDSP_CCA  TDSP_CCH  TDSP_CH1  TDSP_CHG  TDSP_LOG  TDSP_PC1  \
# 0       NaN   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       2.5   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       2.2   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       2.5   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       1.6   NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    TDSP_PCA  TDSP_PCH
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 100 columns]

# %%
df_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 100 columns):
# quarter                332 non-null object
# A067RL1Q156SBEA        289 non-null float64
# A067RL1Q156SBEA_CCA    218 non-null float64
# A067RL1Q156SBEA_CCH    218 non-null float64
# A067RL1Q156SBEA_CH1    285 non-null float64
# A067RL1Q156SBEA_CHG    288 non-null float64
# A067RL1Q156SBEA_LOG    250 non-null float64
# A067RL1Q156SBEA_PC1    285 non-null float64
# A067RL1Q156SBEA_PCA    288 non-null float64
# A067RL1Q156SBEA_PCH    288 non-null float64
# BPCCRO1Q156NBEA        238 non-null float64
# BPCCRO1Q156NBEA_CCA    237 non-null float64
# BPCCRO1Q156NBEA_CCH    237 non-null float64
# BPCCRO1Q156NBEA_CH1    234 non-null float64
# BPCCRO1Q156NBEA_CHG    237 non-null float64
# BPCCRO1Q156NBEA_LOG    238 non-null float64
# BPCCRO1Q156NBEA_PC1    234 non-null float64
# BPCCRO1Q156NBEA_PCA    237 non-null float64
# BPCCRO1Q156NBEA_PCH    237 non-null float64
# CPALTT01USQ659N        238 non-null float64
# CPALTT01USQ659N_CCA    230 non-null float64
# CPALTT01USQ659N_CCH    230 non-null float64
# CPALTT01USQ659N_CH1    234 non-null float64
# CPALTT01USQ659N_CHG    237 non-null float64
# CPALTT01USQ659N_LOG    233 non-null float64
# CPALTT01USQ659N_PC1    234 non-null float64
# CPALTT01USQ659N_PCA    237 non-null float64
# CPALTT01USQ659N_PCH    237 non-null float64
# DPCERO1Q156NBEA        286 non-null float64
# DPCERO1Q156NBEA_CCA    261 non-null float64
# DPCERO1Q156NBEA_CCH    261 non-null float64
# DPCERO1Q156NBEA_CH1    282 non-null float64
# DPCERO1Q156NBEA_CHG    285 non-null float64
# DPCERO1Q156NBEA_LOG    269 non-null float64
# DPCERO1Q156NBEA_PC1    281 non-null float64
# DPCERO1Q156NBEA_PCA    284 non-null float64
# DPCERO1Q156NBEA_PCH    284 non-null float64
# GFDEGDQ188S            214 non-null float64
# GFDEGDQ188S_CCA        213 non-null float64
# GFDEGDQ188S_CCH        213 non-null float64
# GFDEGDQ188S_CH1        210 non-null float64
# GFDEGDQ188S_CHG        213 non-null float64
# GFDEGDQ188S_LOG        214 non-null float64
# GFDEGDQ188S_PC1        210 non-null float64
# GFDEGDQ188S_PCA        213 non-null float64
# GFDEGDQ188S_PCH        213 non-null float64
# GPDI                   290 non-null float64
# GPDI_CCA               289 non-null float64
# GPDI_CCH               289 non-null float64
# GPDI_CH1               286 non-null float64
# GPDI_CHG               289 non-null float64
# GPDI_LOG               290 non-null float64
# GPDI_PC1               286 non-null float64
# GPDI_PCA               289 non-null float64
# GPDI_PCH               289 non-null float64
# M2V                    242 non-null float64
# M2V_CCA                241 non-null float64
# M2V_CCH                241 non-null float64
# M2V_CH1                238 non-null float64
# M2V_CHG                241 non-null float64
# M2V_LOG                242 non-null float64
# M2V_PC1                238 non-null float64
# M2V_PCA                241 non-null float64
# M2V_PCH                241 non-null float64
# MSPUS                  227 non-null float64
# MSPUS_CCA              226 non-null float64
# MSPUS_CCH              226 non-null float64
# MSPUS_CH1              223 non-null float64
# MSPUS_CHG              226 non-null float64
# MSPUS_LOG              227 non-null float64
# MSPUS_PC1              223 non-null float64
# MSPUS_PCA              226 non-null float64
# MSPUS_PCH              226 non-null float64
# NROU                   324 non-null float64
# NROU_CCA               323 non-null float64
# NROU_CCH               323 non-null float64
# NROU_CH1               320 non-null float64
# NROU_CHG               323 non-null float64
# NROU_LOG               324 non-null float64
# NROU_PC1               320 non-null float64
# NROU_PCA               323 non-null float64
# NROU_PCH               323 non-null float64
# PCEC                   290 non-null float64
# PCEC_CCA               289 non-null float64
# PCEC_CCH               289 non-null float64
# PCEC_CH1               286 non-null float64
# PCEC_CHG               289 non-null float64
# PCEC_LOG               290 non-null float64
# PCEC_PC1               286 non-null float64
# PCEC_PCA               289 non-null float64
# PCEC_PCH               289 non-null float64
# TDSP                   158 non-null float64
# TDSP_CCA               157 non-null float64
# TDSP_CCH               157 non-null float64
# TDSP_CH1               154 non-null float64
# TDSP_CHG               157 non-null float64
# TDSP_LOG               158 non-null float64
# TDSP_PC1               154 non-null float64
# TDSP_PCA               157 non-null float64
# TDSP_PCH               157 non-null float64
# dtypes: float64(99), object(1)
# memory usage: 259.5+ KB

# %%
rename_map = {'A067RL1Q156SBEA':'real_disp_pers_inc',
'A067RL1Q156SBEA_CHG':'real_disp_pers_inc_CHG',
'A067RL1Q156SBEA_CH1':'real_disp_pers_inc_CH1',
'A067RL1Q156SBEA_PCH':'real_disp_pers_inc_PCH',
'A067RL1Q156SBEA_PC1':'real_disp_pers_inc_PC1',
'A067RL1Q156SBEA_PCA':'real_disp_pers_inc_PCA',
'A067RL1Q156SBEA_CCH':'real_disp_pers_inc_CCH',
'A067RL1Q156SBEA_CCA':'real_disp_pers_inc_CCA',
'A067RL1Q156SBEA_LOG':'real_disp_pers_inc_LOG',
'BPCCRO1Q156NBEA':'personal_consumption_exp_excl_food_energy',
'BPCCRO1Q156NBEA_CHG':'personal_consumption_exp_excl_food_energy_CHG',
'BPCCRO1Q156NBEA_CH1':'personal_consumption_exp_excl_food_energy_CH1',
'BPCCRO1Q156NBEA_PCH':'personal_consumption_exp_excl_food_energy_PCH',
'BPCCRO1Q156NBEA_PC1':'personal_consumption_exp_excl_food_energy_PC1',
'BPCCRO1Q156NBEA_PCA':'personal_consumption_exp_excl_food_energy_PCA',
'BPCCRO1Q156NBEA_CCH':'personal_consumption_exp_excl_food_energy_CCH',
'BPCCRO1Q156NBEA_CCA':'personal_consumption_exp_excl_food_energy_CCA',
'BPCCRO1Q156NBEA_LOG':'personal_consumption_exp_excl_food_energy_LOG',
'CPALTT01USQ659N':'cpi_US_total',
'CPALTT01USQ659N_CHG':'cpi_US_total_CHG',
'CPALTT01USQ659N_CH1':'cpi_US_total_CH1',
'CPALTT01USQ659N_PCH':'cpi_US_total_PCH',
'CPALTT01USQ659N_PC1':'cpi_US_total_PC1',
'CPALTT01USQ659N_PCA':'cpi_US_total_PCA',
'CPALTT01USQ659N_CCH':'cpi_US_total_CCH',
'CPALTT01USQ659N_CCA':'cpi_US_total_CCA',
'CPALTT01USQ659N_LOG':'cpi_US_total_LOG',
'GFDEGDQ188S':'tot_public_debt_as_pct_of_gdp',
'GFDEGDQ188S_CHG':'tot_public_debt_as_pct_of_gdp_CHG',
'GFDEGDQ188S_CH1':'tot_public_debt_as_pct_of_gdp_CH1',
'GFDEGDQ188S_PCH':'tot_public_debt_as_pct_of_gdp_PCH',
'GFDEGDQ188S_PC1':'tot_public_debt_as_pct_of_gdp_PC1',
'GFDEGDQ188S_PCA':'tot_public_debt_as_pct_of_gdp_PCA',
'GFDEGDQ188S_CCH':'tot_public_debt_as_pct_of_gdp_CCH',
'GFDEGDQ188S_CCA':'tot_public_debt_as_pct_of_gdp_CCA',
'GFDEGDQ188S_LOG':'tot_public_debt_as_pct_of_gdp_LOG',
'GPDI':'gross_private_domestic_invest',
'GPDI_CHG':'gross_private_domestic_invest_CHG',
'GPDI_CH1':'gross_private_domestic_invest_CH1',
'GPDI_PCH':'gross_private_domestic_invest_PCH',
'GPDI_PC1':'gross_private_domestic_invest_PC1',
'GPDI_PCA':'gross_private_domestic_invest_PCA',
'GPDI_CCH':'gross_private_domestic_invest_CCH',
'GPDI_CCA':'gross_private_domestic_invest_CCA',
'GPDI_LOG':'gross_private_domestic_invest_LOG',
'M2V':'M2_velocity',
'M2V_CHG':'M2_velocity_CHG',
'M2V_CH1':'M2_velocity_CH1',
'M2V_PCH':'M2_velocity_PCH',
'M2V_PC1':'M2_velocity_PC1',
'M2V_PCA':'M2_velocity_PCA',
'M2V_CCH':'M2_velocity_CCH',
'M2V_CCA':'M2_velocity_CCA',
'M2V_LOG':'M2_velocity_LOG',
'MSPUS':'median_sls_price_houses_sold_US',
'MSPUS_CHG':'median_sls_price_houses_sold_US_CHG',
'MSPUS_CH1':'median_sls_price_houses_sold_US_CH1',
'MSPUS_PCH':'median_sls_price_houses_sold_US_PCH',
'MSPUS_PC1':'median_sls_price_houses_sold_US_PC1',
'MSPUS_PCA':'median_sls_price_houses_sold_US_PCA',
'MSPUS_CCH':'median_sls_price_houses_sold_US_CCH',
'MSPUS_CCA':'median_sls_price_houses_sold_US_CCA',
'MSPUS_LOG':'median_sls_price_houses_sold_US_LOG',
'NROU':'nat_rate_of_unemp_long_term',
'NROU_CHG':'nat_rate_of_unemp_long_term_CHG',
'NROU_CH1':'nat_rate_of_unemp_long_term_CH1',
'NROU_PCH':'nat_rate_of_unemp_long_term_PCH',
'NROU_PC1':'nat_rate_of_unemp_long_term_PC1',
'NROU_PCA':'nat_rate_of_unemp_long_term_PCA',
'NROU_CCH':'nat_rate_of_unemp_long_term_CCH',
'NROU_CCA':'nat_rate_of_unemp_long_term_CCA',
'NROU_LOG':'nat_rate_of_unemp_long_term_LOG',
'PCEC':'personal_consumption_expenditures',
'PCEC_CHG':'personal_consumption_expenditures_CHG',
'PCEC_CH1':'personal_consumption_expenditures_CH1',
'PCEC_PCH':'personal_consumption_expenditures_PCH',
'PCEC_PC1':'personal_consumption_expenditures_PC1',
'PCEC_PCA':'personal_consumption_expenditures_PCA',
'PCEC_CCH':'personal_consumption_expenditures_CCH',
'PCEC_CCA':'personal_consumption_expenditures_CCA',
'PCEC_LOG':'personal_consumption_expenditures_LOG',
'TDSP':'hh_debt_service_pmts_as_pct_of_disp_personal_income',
'TDSP_CHG':'hh_debt_service_pmts_as_pct_of_disp_personal_income_CHG',
'TDSP_CH1':'hh_debt_service_pmts_as_pct_of_disp_personal_income_CH1',
'TDSP_PCH':'hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH',
'TDSP_PC1':'hh_debt_service_pmts_as_pct_of_disp_personal_income_PC1',
'TDSP_PCA':'hh_debt_service_pmts_as_pct_of_disp_personal_income_PCA',
'TDSP_CCH':'hh_debt_service_pmts_as_pct_of_disp_personal_income_CCH',
'TDSP_CCA':'hh_debt_service_pmts_as_pct_of_disp_personal_income_CCA',
'TDSP_LOG':'hh_debt_service_pmts_as_pct_of_disp_personal_income_LOG'}

# %%
# Rename columns
df_rename = df_rename.rename(rename_map, axis=1)
df_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 100 columns):
# quarter                                                    332 non-null object
# real_disp_pers_inc                                         289 non-null float64
# real_disp_pers_inc_CCA                                     218 non-null float64
# real_disp_pers_inc_CCH                                     218 non-null float64
# real_disp_pers_inc_CH1                                     285 non-null float64
# real_disp_pers_inc_CHG                                     288 non-null float64
# real_disp_pers_inc_LOG                                     250 non-null float64
# real_disp_pers_inc_PC1                                     285 non-null float64
# real_disp_pers_inc_PCA                                     288 non-null float64
# real_disp_pers_inc_PCH                                     288 non-null float64
# personal_consumption_exp_excl_food_energy                  238 non-null float64
# personal_consumption_exp_excl_food_energy_CCA              237 non-null float64
# personal_consumption_exp_excl_food_energy_CCH              237 non-null float64
# personal_consumption_exp_excl_food_energy_CH1              234 non-null float64
# personal_consumption_exp_excl_food_energy_CHG              237 non-null float64
# personal_consumption_exp_excl_food_energy_LOG              238 non-null float64
# personal_consumption_exp_excl_food_energy_PC1              234 non-null float64
# personal_consumption_exp_excl_food_energy_PCA              237 non-null float64
# personal_consumption_exp_excl_food_energy_PCH              237 non-null float64
# cpi_US_total                                               238 non-null float64
# cpi_US_total_CCA                                           230 non-null float64
# cpi_US_total_CCH                                           230 non-null float64
# cpi_US_total_CH1                                           234 non-null float64
# cpi_US_total_CHG                                           237 non-null float64
# cpi_US_total_LOG                                           233 non-null float64
# cpi_US_total_PC1                                           234 non-null float64
# cpi_US_total_PCA                                           237 non-null float64
# cpi_US_total_PCH                                           237 non-null float64
# DPCERO1Q156NBEA                                            286 non-null float64
# DPCERO1Q156NBEA_CCA                                        261 non-null float64
# DPCERO1Q156NBEA_CCH                                        261 non-null float64
# DPCERO1Q156NBEA_CH1                                        282 non-null float64
# DPCERO1Q156NBEA_CHG                                        285 non-null float64
# DPCERO1Q156NBEA_LOG                                        269 non-null float64
# DPCERO1Q156NBEA_PC1                                        281 non-null float64
# DPCERO1Q156NBEA_PCA                                        284 non-null float64
# DPCERO1Q156NBEA_PCH                                        284 non-null float64
# tot_public_debt_as_pct_of_gdp                              214 non-null float64
# tot_public_debt_as_pct_of_gdp_CCA                          213 non-null float64
# tot_public_debt_as_pct_of_gdp_CCH                          213 non-null float64
# tot_public_debt_as_pct_of_gdp_CH1                          210 non-null float64
# tot_public_debt_as_pct_of_gdp_CHG                          213 non-null float64
# tot_public_debt_as_pct_of_gdp_LOG                          214 non-null float64
# tot_public_debt_as_pct_of_gdp_PC1                          210 non-null float64
# tot_public_debt_as_pct_of_gdp_PCA                          213 non-null float64
# tot_public_debt_as_pct_of_gdp_PCH                          213 non-null float64
# gross_private_domestic_invest                              290 non-null float64
# gross_private_domestic_invest_CCA                          289 non-null float64
# gross_private_domestic_invest_CCH                          289 non-null float64
# gross_private_domestic_invest_CH1                          286 non-null float64
# gross_private_domestic_invest_CHG                          289 non-null float64
# gross_private_domestic_invest_LOG                          290 non-null float64
# gross_private_domestic_invest_PC1                          286 non-null float64
# gross_private_domestic_invest_PCA                          289 non-null float64
# gross_private_domestic_invest_PCH                          289 non-null float64
# M2_velocity                                                242 non-null float64
# M2_velocity_CCA                                            241 non-null float64
# M2_velocity_CCH                                            241 non-null float64
# M2_velocity_CH1                                            238 non-null float64
# M2_velocity_CHG                                            241 non-null float64
# M2_velocity_LOG                                            242 non-null float64
# M2_velocity_PC1                                            238 non-null float64
# M2_velocity_PCA                                            241 non-null float64
# M2_velocity_PCH                                            241 non-null float64
# median_sls_price_houses_sold_US                            227 non-null float64
# median_sls_price_houses_sold_US_CCA                        226 non-null float64
# median_sls_price_houses_sold_US_CCH                        226 non-null float64
# median_sls_price_houses_sold_US_CH1                        223 non-null float64
# median_sls_price_houses_sold_US_CHG                        226 non-null float64
# median_sls_price_houses_sold_US_LOG                        227 non-null float64
# median_sls_price_houses_sold_US_PC1                        223 non-null float64
# median_sls_price_houses_sold_US_PCA                        226 non-null float64
# median_sls_price_houses_sold_US_PCH                        226 non-null float64
# nat_rate_of_unemp_long_term                                324 non-null float64
# nat_rate_of_unemp_long_term_CCA                            323 non-null float64
# nat_rate_of_unemp_long_term_CCH                            323 non-null float64
# nat_rate_of_unemp_long_term_CH1                            320 non-null float64
# nat_rate_of_unemp_long_term_CHG                            323 non-null float64
# nat_rate_of_unemp_long_term_LOG                            324 non-null float64
# nat_rate_of_unemp_long_term_PC1                            320 non-null float64
# nat_rate_of_unemp_long_term_PCA                            323 non-null float64
# nat_rate_of_unemp_long_term_PCH                            323 non-null float64
# personal_consumption_expenditures                          290 non-null float64
# personal_consumption_expenditures_CCA                      289 non-null float64
# personal_consumption_expenditures_CCH                      289 non-null float64
# personal_consumption_expenditures_CH1                      286 non-null float64
# personal_consumption_expenditures_CHG                      289 non-null float64
# personal_consumption_expenditures_LOG                      290 non-null float64
# personal_consumption_expenditures_PC1                      286 non-null float64
# personal_consumption_expenditures_PCA                      289 non-null float64
# personal_consumption_expenditures_PCH                      289 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income        158 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CCA    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CCH    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CH1    154 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CHG    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_LOG    158 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PC1    154 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PCA    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH    157 non-null float64
# dtypes: float64(99), object(1)
# memory usage: 259.5+ KB

# %%
df_rename.quarter.sort_values()[:10]
# Out:
# 0    1947Q1
# 1    1947Q2
# 2    1947Q3
# 3    1947Q4
# 4    1948Q1
# 5    1948Q2
# 6    1948Q3
# 7    1948Q4
# 8    1949Q1
# 9    1949Q2
# Name: quarter, dtype: object

# %%
df_rename.quarter.sort_values(ascending=False)[:10]
# Out:
# 331    2029Q4
# 330    2029Q3
# 329    2029Q2
# 328    2029Q1
# 327    2028Q4
# 326    2028Q3
# 325    2028Q2
# 324    2028Q1
# 323    2027Q4
# 322    2027Q3
# Name: quarter, dtype: object

# %%
df_rename['year'] = df_rename['quarter'].apply(lambda x: x[:4])

df_rename.head()

df_subset = df_rename[
    (df_rename['year'].astype(int) < 2020) & 
    (df_rename['quarter'] != '2019Q3') &
    (df_rename['quarter'] != '2019Q4')]
df_subset.tail()
# Out:
#     quarter  real_disp_pers_inc  real_disp_pers_inc_CCA  \
# 285  2018Q2                 2.7                  -375.3
# 286  2018Q3                 3.3                    80.3
# 287  2018Q4                 2.8                   -65.7
# 288  2019Q1                 4.5                   189.8
# 289  2019Q2                 2.4                  -251.4
#
#      real_disp_pers_inc_CCH  real_disp_pers_inc_CH1  real_disp_pers_inc_CHG  \
# 285                   -93.8                     0.0                    -4.2
# 286                    20.1                     1.0                     0.6
# 287                   -16.4                    -0.9                    -0.5
# 288                    47.4                    -2.4                     1.7
# 289                   -62.9                    -0.3                    -2.1
#
#      real_disp_pers_inc_LOG  real_disp_pers_inc_PC1  real_disp_pers_inc_PCA  \
# 285                     1.0                     0.0                   -97.7
# 286                     1.2                    43.5                   123.2
# 287                     1.0                   -24.3                   -48.2
# 288                     1.5                   -34.8                   567.1
# 289                     0.9                   -11.1                   -91.9
#
#      real_disp_pers_inc_PCH  ...  \
# 285                   -60.9  ...
# 286                    22.2  ...
# 287                   -15.2  ...
# 288                    60.7  ...
# 289                   -46.7  ...
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income  \
# 285                                           9.701680
# 286                                           9.691628
# 287                                           9.741203
# 288                                           9.710218
# 289                                           9.687619
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_CCA  \
# 285                                               -1.3
# 286                                               -0.4
# 287                                                2.0
# 288                                               -1.3
# 289                                               -0.9
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_CCH  \
# 285                                               -0.3
# 286                                               -0.1
# 287                                                0.5
# 288                                               -0.3
# 289                                               -0.2
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_CH1  \
# 285                                          -0.257747
# 286                                          -0.247451
# 287                                          -0.134892
# 288                                          -0.022966
# 289                                          -0.014061
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_CHG  \
# 285                                          -0.031504
# 286                                          -0.010052
# 287                                           0.049575
# 288                                          -0.030985
# 289                                          -0.022599
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_LOG  \
# 285                                                2.3
# 286                                                2.3
# 287                                                2.3
# 288                                                2.3
# 289                                                2.3
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_PC1  \
# 285                                               -2.6
# 286                                               -2.5
# 287                                               -1.4
# 288                                               -0.2
# 289                                               -0.1
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_PCA  \
# 285                                               -1.3
# 286                                               -0.4
# 287                                                2.1
# 288                                               -1.3
# 289                                               -0.9
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH  year
# 285                                               -0.3        2018
# 286                                               -0.1        2018
# 287                                                0.5        2018
# 288                                               -0.3        2019
# 289                                               -0.2        2019
#
# [5 rows x 101 columns]

# %%
df_subset.info(verbose=True, null_counts=True)

# 290 possible values from 1947Q1 to 2019Q2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290 entries, 0 to 289
# Data columns (total 101 columns):
# quarter                                                    290 non-null object
# real_disp_pers_inc                                         289 non-null float64
# real_disp_pers_inc_CCA                                     218 non-null float64
# real_disp_pers_inc_CCH                                     218 non-null float64
# real_disp_pers_inc_CH1                                     285 non-null float64
# real_disp_pers_inc_CHG                                     288 non-null float64
# real_disp_pers_inc_LOG                                     250 non-null float64
# real_disp_pers_inc_PC1                                     285 non-null float64
# real_disp_pers_inc_PCA                                     288 non-null float64
# real_disp_pers_inc_PCH                                     288 non-null float64
# personal_consumption_exp_excl_food_energy                  238 non-null float64
# personal_consumption_exp_excl_food_energy_CCA              237 non-null float64
# personal_consumption_exp_excl_food_energy_CCH              237 non-null float64
# personal_consumption_exp_excl_food_energy_CH1              234 non-null float64
# personal_consumption_exp_excl_food_energy_CHG              237 non-null float64
# personal_consumption_exp_excl_food_energy_LOG              238 non-null float64
# personal_consumption_exp_excl_food_energy_PC1              234 non-null float64
# personal_consumption_exp_excl_food_energy_PCA              237 non-null float64
# personal_consumption_exp_excl_food_energy_PCH              237 non-null float64
# cpi_US_total                                               238 non-null float64
# cpi_US_total_CCA                                           230 non-null float64
# cpi_US_total_CCH                                           230 non-null float64
# cpi_US_total_CH1                                           234 non-null float64
# cpi_US_total_CHG                                           237 non-null float64
# cpi_US_total_LOG                                           233 non-null float64
# cpi_US_total_PC1                                           234 non-null float64
# cpi_US_total_PCA                                           237 non-null float64
# cpi_US_total_PCH                                           237 non-null float64
# DPCERO1Q156NBEA                                            286 non-null float64
# DPCERO1Q156NBEA_CCA                                        261 non-null float64
# DPCERO1Q156NBEA_CCH                                        261 non-null float64
# DPCERO1Q156NBEA_CH1                                        282 non-null float64
# DPCERO1Q156NBEA_CHG                                        285 non-null float64
# DPCERO1Q156NBEA_LOG                                        269 non-null float64
# DPCERO1Q156NBEA_PC1                                        281 non-null float64
# DPCERO1Q156NBEA_PCA                                        284 non-null float64
# DPCERO1Q156NBEA_PCH                                        284 non-null float64
# tot_public_debt_as_pct_of_gdp                              214 non-null float64
# tot_public_debt_as_pct_of_gdp_CCA                          213 non-null float64
# tot_public_debt_as_pct_of_gdp_CCH                          213 non-null float64
# tot_public_debt_as_pct_of_gdp_CH1                          210 non-null float64
# tot_public_debt_as_pct_of_gdp_CHG                          213 non-null float64
# tot_public_debt_as_pct_of_gdp_LOG                          214 non-null float64
# tot_public_debt_as_pct_of_gdp_PC1                          210 non-null float64
# tot_public_debt_as_pct_of_gdp_PCA                          213 non-null float64
# tot_public_debt_as_pct_of_gdp_PCH                          213 non-null float64
# gross_private_domestic_invest                              290 non-null float64
# gross_private_domestic_invest_CCA                          289 non-null float64
# gross_private_domestic_invest_CCH                          289 non-null float64
# gross_private_domestic_invest_CH1                          286 non-null float64
# gross_private_domestic_invest_CHG                          289 non-null float64
# gross_private_domestic_invest_LOG                          290 non-null float64
# gross_private_domestic_invest_PC1                          286 non-null float64
# gross_private_domestic_invest_PCA                          289 non-null float64
# gross_private_domestic_invest_PCH                          289 non-null float64
# M2_velocity                                                242 non-null float64
# M2_velocity_CCA                                            241 non-null float64
# M2_velocity_CCH                                            241 non-null float64
# M2_velocity_CH1                                            238 non-null float64
# M2_velocity_CHG                                            241 non-null float64
# M2_velocity_LOG                                            242 non-null float64
# M2_velocity_PC1                                            238 non-null float64
# M2_velocity_PCA                                            241 non-null float64
# M2_velocity_PCH                                            241 non-null float64
# median_sls_price_houses_sold_US                            226 non-null float64
# median_sls_price_houses_sold_US_CCA                        225 non-null float64
# median_sls_price_houses_sold_US_CCH                        225 non-null float64
# median_sls_price_houses_sold_US_CH1                        222 non-null float64
# median_sls_price_houses_sold_US_CHG                        225 non-null float64
# median_sls_price_houses_sold_US_LOG                        226 non-null float64
# median_sls_price_houses_sold_US_PC1                        222 non-null float64
# median_sls_price_houses_sold_US_PCA                        225 non-null float64
# median_sls_price_houses_sold_US_PCH                        225 non-null float64
# nat_rate_of_unemp_long_term                                282 non-null float64
# nat_rate_of_unemp_long_term_CCA                            281 non-null float64
# nat_rate_of_unemp_long_term_CCH                            281 non-null float64
# nat_rate_of_unemp_long_term_CH1                            278 non-null float64
# nat_rate_of_unemp_long_term_CHG                            281 non-null float64
# nat_rate_of_unemp_long_term_LOG                            282 non-null float64
# nat_rate_of_unemp_long_term_PC1                            278 non-null float64
# nat_rate_of_unemp_long_term_PCA                            281 non-null float64
# nat_rate_of_unemp_long_term_PCH                            281 non-null float64
# personal_consumption_expenditures                          290 non-null float64
# personal_consumption_expenditures_CCA                      289 non-null float64
# personal_consumption_expenditures_CCH                      289 non-null float64
# personal_consumption_expenditures_CH1                      286 non-null float64
# personal_consumption_expenditures_CHG                      289 non-null float64
# personal_consumption_expenditures_LOG                      290 non-null float64
# personal_consumption_expenditures_PC1                      286 non-null float64
# personal_consumption_expenditures_PCA                      289 non-null float64
# personal_consumption_expenditures_PCH                      289 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income        158 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CCA    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CCH    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CH1    154 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CHG    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_LOG    158 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PC1    154 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PCA    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH    157 non-null float64
# year                                                       290 non-null object
# dtypes: float64(99), object(2)
# memory usage: 231.1+ KB

# %%
# Check for null values
null_data = df_subset[df_subset.isnull().any(axis=1)]
null_data
# Out:
#     quarter  real_disp_pers_inc  real_disp_pers_inc_CCA  \
# 0    1947Q1                 NaN                     NaN
# 1    1947Q2                -3.8                     NaN
# 2    1947Q3                11.1                     NaN
# 3    1947Q4                -5.5                     NaN
# 4    1948Q1                 7.7                     NaN
# 5    1948Q2                13.0                   209.5
# 6    1948Q3                 6.7                  -265.1
# 7    1948Q4                 2.3                  -427.7
# 8    1949Q1                -7.6                     NaN
# 9    1949Q2                 2.0                     NaN
# 10   1949Q3                 2.6                   104.9
# 11   1949Q4                 2.3                   -49.0
# 12   1950Q1                34.6                  1084.4
# 13   1950Q2                -1.2                     NaN
# 14   1950Q3                 5.1                     NaN
# 15   1950Q4                 2.5                  -285.2
# 16   1951Q1                 0.4                  -733.0
# 17   1951Q2                 9.2                  1254.2
# 18   1951Q3                 4.6                  -277.3
# 19   1951Q4                -0.7                     NaN
# 20   1952Q1                -0.2                     NaN
# 21   1952Q2                 5.2                     NaN
# 22   1952Q3                 8.3                   187.0
# 23   1952Q4                 8.9                    27.9
# 24   1953Q1                 4.8                  -247.0
# 25   1953Q2                 5.3                    39.6
# 26   1953Q3                -1.9                     NaN
# 27   1953Q4                -1.3                     NaN
# 28   1954Q1                 2.0                     NaN
# 29   1954Q2                 0.4                  -643.8
# ..      ...                 ...                     ...
# 174  1990Q3                -0.1                     NaN
# 175  1990Q4                -3.4                     NaN
# 176  1991Q1                 1.0                     NaN
# 177  1991Q2                 3.0                   439.4
# 217  2001Q2                -0.7                     NaN
# 218  2001Q3                 9.6                     NaN
# 219  2001Q4                -5.0                     NaN
# 220  2002Q1                 9.3                     NaN
# 222  2002Q3                -0.3                     NaN
# 223  2002Q4                 2.4                     NaN
# 232  2005Q1                -4.6                     NaN
# 233  2005Q2                 3.9                     NaN
# 246  2008Q3                -8.1                     NaN
# 247  2008Q4                 3.5                     NaN
# 248  2009Q1                -1.7                     NaN
# 249  2009Q2                 4.4                     NaN
# 250  2009Q3                -4.4                     NaN
# 251  2009Q4                -0.1                     NaN
# 252  2010Q1                 2.3                     NaN
# 257  2011Q2                -0.9                     NaN
# 258  2011Q3                 1.8                     NaN
# 262  2012Q3                -2.8                     NaN
# 263  2012Q4                11.6                     NaN
# 264  2013Q1               -15.1                     NaN
# 265  2013Q2                 3.0                     NaN
# 272  2015Q1                 4.6                   -64.1
# 273  2015Q2                 3.0                  -171.0
# 274  2015Q3                 3.0                     0.0
# 277  2016Q2                -0.4                     NaN
# 278  2016Q3                 1.8                     NaN
#
#      real_disp_pers_inc_CCH  real_disp_pers_inc_CH1  real_disp_pers_inc_CHG  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                    14.9
# 3                       NaN                     NaN                   -16.6
# 4                       NaN                     NaN                    13.2
# 5                      52.4                    16.8                     5.3
# 6                     -66.3                    -4.4                    -6.3
# 7                    -106.9                     7.8                    -4.4
# 8                       NaN                   -15.3                    -9.9
# 9                       NaN                   -11.0                     9.6
# 10                     26.2                    -4.1                     0.6
# 11                    -12.3                     0.0                    -0.3
# 12                    271.1                    42.2                    32.3
# 13                      NaN                    -3.2                   -35.8
# 14                      NaN                     2.5                     6.3
# 15                    -71.3                     0.2                    -2.6
# 16                   -183.3                   -34.2                    -2.1
# 17                    313.5                    10.4                     8.8
# 18                    -69.3                    -0.5                    -4.6
# 19                      NaN                    -3.2                    -5.3
# 20                      NaN                    -0.6                     0.5
# 21                      NaN                    -4.0                     5.4
# 22                     46.8                     3.7                     3.1
# 23                      7.0                     9.6                     0.6
# 24                    -61.7                     5.0                    -4.1
# 25                      9.9                     0.1                     0.5
# 26                      NaN                   -10.2                    -7.2
# 27                      NaN                   -10.2                     0.6
# 28                      NaN                    -2.8                     3.3
# 29                   -160.9                    -4.9                    -1.6
# ..                      ...                     ...                     ...
# 174                     NaN                    -2.8                    -2.9
# 175                     NaN                    -6.8                    -3.3
# 176                     NaN                    -2.1                     4.4
# 177                   109.9                     0.2                     2.0
# 217                     NaN                    -5.2                    -4.4
# 218                     NaN                     4.9                    10.3
# 219                     NaN                    -6.4                   -14.6
# 220                     NaN                     5.6                    14.3
# 222                     NaN                    -9.9                    -3.0
# 223                     NaN                     7.4                     2.7
# 232                     NaN                    -6.5                    -9.7
# 233                     NaN                    -0.8                     8.5
# 246                     NaN                    -8.5                   -15.6
# 247                     NaN                     3.2                    11.6
# 248                     NaN                    -2.8                    -5.2
# 249                     NaN                    -3.1                     6.1
# 250                     NaN                     3.7                    -8.8
# 251                     NaN                    -3.6                     4.3
# 252                     NaN                     4.0                     2.4
# 257                     NaN                    -7.7                    -5.0
# 258                     NaN                    -1.1                     2.7
# 262                     NaN                    -4.6                    -6.5
# 263                     NaN                    10.4                    14.4
# 264                     NaN                   -22.8                   -26.7
# 265                     NaN                    -0.7                    18.1
# 272                   -16.0                    -1.1                    -0.8
# 273                   -42.7                    -2.6                    -1.6
# 274                     0.0                    -1.8                     0.0
# 277                     NaN                    -3.4                    -3.1
# 278                     NaN                    -1.2                     2.2
#
#      real_disp_pers_inc_LOG  real_disp_pers_inc_PC1  real_disp_pers_inc_PCA  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       2.4                     NaN                  7180.4
# 3                       NaN                     NaN                   -94.0
# 4                       2.0                     NaN                   284.2
# 5                       2.6                  -442.1                   712.5
# 6                       1.9                   -39.6                   -92.9
# 7                       0.8                  -141.8                   -98.6
# 8                       NaN                  -198.7                 11821.8
# 9                       0.7                   -84.6                   -99.5
# 10                      1.0                   -61.2                   185.6
# 11                      0.8                     0.0                   -38.8
# 12                      3.5                  -555.3               5121351.3
# 13                      NaN                  -160.0                  -100.0
# 14                      1.6                    96.2                 32525.4
# 15                      0.9                     8.7                   -94.2
# 16                     -0.9                   -98.8                   -99.9
# 17                      2.2                  -866.7              27984000.0
# 18                      1.5                    -9.8                   -93.8
# 19                      NaN                  -128.0                   -99.9
# 20                      NaN                  -150.0                   -99.3
# 21                      1.6                   -43.5              45697500.0
# 22                      2.1                    80.4                   549.1
# 23                      2.2                 -1371.4                    32.2
# 24                      1.6                 -2500.0                   -91.5
# 25                      1.7                     1.9                    48.6
# 26                      NaN                  -122.9                   -98.3
# 27                      NaN                  -114.6                   -78.1
# 28                      0.7                   -58.3                   460.2
# 29                     -0.9                   -92.5                   -99.8
# ..                      ...                     ...                     ...
# 174                     NaN                  -103.7                  -100.0
# 175                     NaN                  -200.0             133633500.0
# 176                     0.0                   -67.7                   -99.3
# 177                     1.1                     7.1                  8000.0
# 217                     NaN                  -115.6                   -99.9
# 218                     2.3                   104.3               3537370.1
# 219                     NaN                  -457.1                   -92.6
# 220                     2.2                   151.4                  1096.9
# 222                     NaN                  -103.1                  -100.0
# 223                     0.9                  -148.0                409500.0
# 232                     NaN                  -342.1                   -33.8
# 233                     1.4                   -17.0                   -48.3
# 246                     NaN                 -2125.0                    36.0
# 247                     1.3                  1066.7                   -96.5
# 248                     NaN                  -254.5                   -94.4
# 249                     1.5                   -41.3                  4387.6
# 250                     NaN                   -45.7                     0.0
# 251                     NaN                  -102.9                  -100.0
# 252                     0.8                  -235.3              27984000.0
# 257                     NaN                  -113.2                   -99.8
# 258                     0.6                   -37.9                  1500.0
# 262                     NaN                  -255.6                   -67.2
# 263                     2.5                   866.7                 29357.8
# 264                     NaN                  -296.1                   187.1
# 265                     1.1                   -18.9                   -99.8
# 272                     1.5                   -19.3                   -47.3
# 273                     1.1                   -46.4                   -81.9
# 274                     1.1                   -37.5                     0.0
# 277                     NaN                  -113.3                  -100.0
# 278                     0.6                   -40.0                 40906.3
#
#      real_disp_pers_inc_PCH  ...  \
# 0                       NaN  ...
# 1                       NaN  ...
# 2                    -392.1  ...
# 3                    -149.5  ...
# 4                    -240.0  ...
# 5                      68.8  ...
# 6                     -48.5  ...
# 7                     -65.7  ...
# 8                    -430.4  ...
# 9                    -126.3  ...
# 10                     30.0  ...
# 11                    -11.5  ...
# 12                   1404.3  ...
# 13                   -103.5  ...
# 14                   -525.0  ...
# 15                    -51.0  ...
# 16                    -84.0  ...
# 17                   2200.0  ...
# 18                    -50.0  ...
# 19                   -115.2  ...
# 20                    -71.4  ...
# 21                  -2700.0  ...
# 22                     59.6  ...
# 23                      7.2  ...
# 24                    -46.1  ...
# 25                     10.4  ...
# 26                   -135.8  ...
# 27                    -31.6  ...
# 28                   -253.8  ...
# 29                    -80.0  ...
# ..                      ...  ...
# 174                  -103.6  ...
# 175                  3300.0  ...
# 176                  -129.4  ...
# 177                   200.0  ...
# 217                  -118.9  ...
# 218                 -1471.4  ...
# 219                  -152.1  ...
# 220                  -286.0  ...
# 222                  -111.1  ...
# 223                  -900.0  ...
# 232                  -190.2  ...
# 233                  -184.8  ...
# 246                  -208.0  ...
# 247                  -143.2  ...
# 248                  -148.6  ...
# 249                  -358.8  ...
# 250                  -200.0  ...
# 251                   -97.7  ...
# 252                 -2400.0  ...
# 257                  -122.0  ...
# 258                  -300.0  ...
# 262                  -175.7  ...
# 263                  -514.3  ...
# 264                  -230.2  ...
# 265                  -119.9  ...
# 272                   -14.8  ...
# 273                   -34.8  ...
# 274                     0.0  ...
# 277                  -114.8  ...
# 278                  -550.0  ...
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 174                                          11.583131
# 175                                          11.604449
# 176                                          11.578032
# 177                                          11.434237
# 217                                          12.383873
# 218                                          12.323468
# 219                                          12.622859
# 220                                          12.416701
# 222                                          12.377254
# 223                                          12.346926
# 232                                          12.558832
# 233                                          12.560029
# 246                                          12.874881
# 247                                          12.824806
# 248                                          12.755924
# 249                                          12.370505
# 250                                          12.235962
# 251                                          11.962675
# 252                                          11.681821
# 257                                          10.686568
# 258                                          10.577200
# 262                                          10.143950
# 263                                           9.828265
# 264                                          10.188552
# 265                                          10.112273
# 272                                           9.918526
# 273                                           9.910980
# 274                                           9.951684
# 277                                           9.997024
# 278                                          10.059204
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_CCA  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 174                                               -0.6
# 175                                                0.7
# 176                                               -0.9
# 177                                               -5.0
# 217                                                7.3
# 218                                               -2.0
# 219                                                9.6
# 220                                               -6.6
# 222                                                1.3
# 223                                               -1.0
# 232                                               10.4
# 233                                                0.0
# 246                                                2.6
# 247                                               -1.6
# 248                                               -2.2
# 249                                              -12.3
# 250                                               -4.4
# 251                                               -9.0
# 252                                               -9.5
# 257                                               -3.2
# 258                                               -4.1
# 262                                                2.6
# 263                                              -12.6
# 264                                               14.4
# 265                                               -3.0
# 272                                                2.5
# 273                                               -0.3
# 274                                                1.6
# 277                                                3.9
# 278                                                2.5
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_CCH  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 174                                               -0.2
# 175                                                0.2
# 176                                               -0.2
# 177                                               -1.2
# 217                                                1.8
# 218                                               -0.5
# 219                                                2.4
# 220                                               -1.6
# 222                                                0.3
# 223                                               -0.2
# 232                                                2.6
# 233                                                0.0
# 246                                                0.6
# 247                                               -0.4
# 248                                               -0.5
# 249                                               -3.1
# 250                                               -1.1
# 251                                               -2.3
# 252                                               -2.4
# 257                                               -0.8
# 258                                               -1.0
# 262                                                0.7
# 263                                               -3.2
# 264                                                3.6
# 265                                               -0.8
# 272                                                0.6
# 273                                               -0.1
# 274                                                0.4
# 277                                                1.0
# 278                                                0.6
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_CH1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 174                                          -0.210746
# 175                                          -0.141230
# 176                                          -0.071118
# 177                                          -0.166423
# 217                                           0.723932
# 218                                           0.486843
# 219                                           0.559514
# 220                                           0.255711
# 222                                           0.053786
# 223                                          -0.275933
# 232                                           0.348691
# 233                                           0.428007
# 246                                          -0.201895
# 247                                          -0.390582
# 248                                          -0.379705
# 249                                          -0.421560
# 250                                          -0.638919
# 251                                          -0.862131
# 252                                          -1.074103
# 257                                          -0.663567
# 258                                          -0.566993
# 262                                          -0.433250
# 263                                          -0.622009
# 264                                          -0.012043
# 265                                           0.034346
# 272                                          -0.058879
# 273                                          -0.002740
# 274                                           0.078156
# 277                                           0.086044
# 278                                           0.107520
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_CHG  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 174                                          -0.017529
# 175                                           0.021318
# 176                                          -0.026417
# 177                                          -0.143795
# 217                                           0.222883
# 218                                          -0.060405
# 219                                           0.299391
# 220                                          -0.206158
# 222                                           0.040883
# 223                                          -0.030328
# 232                                           0.321615
# 233                                           0.001197
# 246                                           0.082816
# 247                                          -0.050075
# 248                                          -0.068882
# 249                                          -0.385419
# 250                                          -0.134543
# 251                                          -0.273287
# 252                                          -0.280854
# 257                                          -0.087088
# 258                                          -0.109368
# 262                                           0.066023
# 263                                          -0.315685
# 264                                           0.360287
# 265                                          -0.076279
# 272                                           0.062594
# 273                                          -0.007546
# 274                                           0.040704
# 277                                           0.097104
# 278                                           0.062180
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_LOG  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 174                                                2.4
# 175                                                2.5
# 176                                                2.4
# 177                                                2.4
# 217                                                2.5
# 218                                                2.5
# 219                                                2.5
# 220                                                2.5
# 222                                                2.5
# 223                                                2.5
# 232                                                2.5
# 233                                                2.5
# 246                                                2.6
# 247                                                2.6
# 248                                                2.5
# 249                                                2.5
# 250                                                2.5
# 251                                                2.5
# 252                                                2.5
# 257                                                2.4
# 258                                                2.4
# 262                                                2.3
# 263                                                2.3
# 264                                                2.3
# 265                                                2.3
# 272                                                2.3
# 273                                                2.3
# 274                                                2.3
# 277                                                2.3
# 278                                                2.3
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_PC1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 174                                               -1.8
# 175                                               -1.2
# 176                                               -0.6
# 177                                               -1.4
# 217                                                6.2
# 218                                                4.1
# 219                                                4.6
# 220                                                2.1
# 222                                                0.4
# 223                                               -2.2
# 232                                                2.9
# 233                                                3.5
# 246                                               -1.5
# 247                                               -3.0
# 248                                               -2.9
# 249                                               -3.3
# 250                                               -5.0
# 251                                               -6.7
# 252                                               -8.4
# 257                                               -5.8
# 258                                               -5.1
# 262                                               -4.1
# 263                                               -6.0
# 264                                               -0.1
# 265                                                0.3
# 272                                               -0.6
# 273                                                0.0
# 274                                                0.8
# 277                                                0.9
# 278                                                1.1
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_PCA  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 174                                               -0.6
# 175                                                0.7
# 176                                               -0.9
# 177                                               -4.9
# 217                                                7.5
# 218                                               -1.9
# 219                                               10.1
# 220                                               -6.4
# 222                                                1.3
# 223                                               -1.0
# 232                                               10.9
# 233                                                0.0
# 246                                                2.6
# 247                                               -1.5
# 248                                               -2.1
# 249                                              -11.5
# 250                                               -4.3
# 251                                               -8.6
# 252                                               -9.1
# 257                                               -3.2
# 258                                               -4.0
# 262                                                2.6
# 263                                              -11.9
# 264                                               15.5
# 265                                               -3.0
# 272                                                2.6
# 273                                               -0.3
# 274                                                1.7
# 277                                                4.0
# 278                                                2.5
#
#      hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH  year
# 0                                                  NaN        1947
# 1                                                  NaN        1947
# 2                                                  NaN        1947
# 3                                                  NaN        1947
# 4                                                  NaN        1948
# 5                                                  NaN        1948
# 6                                                  NaN        1948
# 7                                                  NaN        1948
# 8                                                  NaN        1949
# 9                                                  NaN        1949
# 10                                                 NaN        1949
# 11                                                 NaN        1949
# 12                                                 NaN        1950
# 13                                                 NaN        1950
# 14                                                 NaN        1950
# 15                                                 NaN        1950
# 16                                                 NaN        1951
# 17                                                 NaN        1951
# 18                                                 NaN        1951
# 19                                                 NaN        1951
# 20                                                 NaN        1952
# 21                                                 NaN        1952
# 22                                                 NaN        1952
# 23                                                 NaN        1952
# 24                                                 NaN        1953
# 25                                                 NaN        1953
# 26                                                 NaN        1953
# 27                                                 NaN        1953
# 28                                                 NaN        1954
# 29                                                 NaN        1954
# ..                                                 ...         ...
# 174                                               -0.2        1990
# 175                                                0.2        1990
# 176                                               -0.2        1991
# 177                                               -1.2        1991
# 217                                                1.8        2001
# 218                                               -0.5        2001
# 219                                                2.4        2001
# 220                                               -1.6        2002
# 222                                                0.3        2002
# 223                                               -0.2        2002
# 232                                                2.6        2005
# 233                                                0.0        2005
# 246                                                0.6        2008
# 247                                               -0.4        2008
# 248                                               -0.5        2009
# 249                                               -3.0        2009
# 250                                               -1.1        2009
# 251                                               -2.2        2009
# 252                                               -2.3        2010
# 257                                               -0.8        2011
# 258                                               -1.0        2011
# 262                                                0.7        2012
# 263                                               -3.1        2012
# 264                                                3.7        2013
# 265                                               -0.7        2013
# 272                                                0.6        2015
# 273                                               -0.1        2015
# 274                                                0.4        2015
# 277                                                1.0        2016
# 278                                                0.6        2016
#
# [177 rows x 101 columns]

# %%
null_data.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177 entries, 0 to 278
# Data columns (total 101 columns):
# quarter                                                    177 non-null object
# real_disp_pers_inc                                         176 non-null float64
# real_disp_pers_inc_CCA                                     105 non-null float64
# real_disp_pers_inc_CCH                                     105 non-null float64
# real_disp_pers_inc_CH1                                     172 non-null float64
# real_disp_pers_inc_CHG                                     175 non-null float64
# real_disp_pers_inc_LOG                                     137 non-null float64
# real_disp_pers_inc_PC1                                     172 non-null float64
# real_disp_pers_inc_PCA                                     175 non-null float64
# real_disp_pers_inc_PCH                                     175 non-null float64
# personal_consumption_exp_excl_food_energy                  125 non-null float64
# personal_consumption_exp_excl_food_energy_CCA              124 non-null float64
# personal_consumption_exp_excl_food_energy_CCH              124 non-null float64
# personal_consumption_exp_excl_food_energy_CH1              121 non-null float64
# personal_consumption_exp_excl_food_energy_CHG              124 non-null float64
# personal_consumption_exp_excl_food_energy_LOG              125 non-null float64
# personal_consumption_exp_excl_food_energy_PC1              121 non-null float64
# personal_consumption_exp_excl_food_energy_PCA              124 non-null float64
# personal_consumption_exp_excl_food_energy_PCH              124 non-null float64
# cpi_US_total                                               125 non-null float64
# cpi_US_total_CCA                                           117 non-null float64
# cpi_US_total_CCH                                           117 non-null float64
# cpi_US_total_CH1                                           121 non-null float64
# cpi_US_total_CHG                                           124 non-null float64
# cpi_US_total_LOG                                           120 non-null float64
# cpi_US_total_PC1                                           121 non-null float64
# cpi_US_total_PCA                                           124 non-null float64
# cpi_US_total_PCH                                           124 non-null float64
# DPCERO1Q156NBEA                                            173 non-null float64
# DPCERO1Q156NBEA_CCA                                        148 non-null float64
# DPCERO1Q156NBEA_CCH                                        148 non-null float64
# DPCERO1Q156NBEA_CH1                                        169 non-null float64
# DPCERO1Q156NBEA_CHG                                        172 non-null float64
# DPCERO1Q156NBEA_LOG                                        156 non-null float64
# DPCERO1Q156NBEA_PC1                                        168 non-null float64
# DPCERO1Q156NBEA_PCA                                        171 non-null float64
# DPCERO1Q156NBEA_PCH                                        171 non-null float64
# tot_public_debt_as_pct_of_gdp                              101 non-null float64
# tot_public_debt_as_pct_of_gdp_CCA                          100 non-null float64
# tot_public_debt_as_pct_of_gdp_CCH                          100 non-null float64
# tot_public_debt_as_pct_of_gdp_CH1                          97 non-null float64
# tot_public_debt_as_pct_of_gdp_CHG                          100 non-null float64
# tot_public_debt_as_pct_of_gdp_LOG                          101 non-null float64
# tot_public_debt_as_pct_of_gdp_PC1                          97 non-null float64
# tot_public_debt_as_pct_of_gdp_PCA                          100 non-null float64
# tot_public_debt_as_pct_of_gdp_PCH                          100 non-null float64
# gross_private_domestic_invest                              177 non-null float64
# gross_private_domestic_invest_CCA                          176 non-null float64
# gross_private_domestic_invest_CCH                          176 non-null float64
# gross_private_domestic_invest_CH1                          173 non-null float64
# gross_private_domestic_invest_CHG                          176 non-null float64
# gross_private_domestic_invest_LOG                          177 non-null float64
# gross_private_domestic_invest_PC1                          173 non-null float64
# gross_private_domestic_invest_PCA                          176 non-null float64
# gross_private_domestic_invest_PCH                          176 non-null float64
# M2_velocity                                                129 non-null float64
# M2_velocity_CCA                                            128 non-null float64
# M2_velocity_CCH                                            128 non-null float64
# M2_velocity_CH1                                            125 non-null float64
# M2_velocity_CHG                                            128 non-null float64
# M2_velocity_LOG                                            129 non-null float64
# M2_velocity_PC1                                            125 non-null float64
# M2_velocity_PCA                                            128 non-null float64
# M2_velocity_PCH                                            128 non-null float64
# median_sls_price_houses_sold_US                            113 non-null float64
# median_sls_price_houses_sold_US_CCA                        112 non-null float64
# median_sls_price_houses_sold_US_CCH                        112 non-null float64
# median_sls_price_houses_sold_US_CH1                        109 non-null float64
# median_sls_price_houses_sold_US_CHG                        112 non-null float64
# median_sls_price_houses_sold_US_LOG                        113 non-null float64
# median_sls_price_houses_sold_US_PC1                        109 non-null float64
# median_sls_price_houses_sold_US_PCA                        112 non-null float64
# median_sls_price_houses_sold_US_PCH                        112 non-null float64
# nat_rate_of_unemp_long_term                                169 non-null float64
# nat_rate_of_unemp_long_term_CCA                            168 non-null float64
# nat_rate_of_unemp_long_term_CCH                            168 non-null float64
# nat_rate_of_unemp_long_term_CH1                            165 non-null float64
# nat_rate_of_unemp_long_term_CHG                            168 non-null float64
# nat_rate_of_unemp_long_term_LOG                            169 non-null float64
# nat_rate_of_unemp_long_term_PC1                            165 non-null float64
# nat_rate_of_unemp_long_term_PCA                            168 non-null float64
# nat_rate_of_unemp_long_term_PCH                            168 non-null float64
# personal_consumption_expenditures                          177 non-null float64
# personal_consumption_expenditures_CCA                      176 non-null float64
# personal_consumption_expenditures_CCH                      176 non-null float64
# personal_consumption_expenditures_CH1                      173 non-null float64
# personal_consumption_expenditures_CHG                      176 non-null float64
# personal_consumption_expenditures_LOG                      177 non-null float64
# personal_consumption_expenditures_PC1                      173 non-null float64
# personal_consumption_expenditures_PCA                      176 non-null float64
# personal_consumption_expenditures_PCH                      176 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income        45 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CCA    44 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CCH    44 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CH1    41 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CHG    44 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_LOG    45 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PC1    41 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PCA    44 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH    44 non-null float64
# year                                                       177 non-null object
# dtypes: float64(99), object(2)
# memory usage: 141.0+ KB
# NoneType

# %%
df_subset.to_csv('../resources/FRED_data.csv', index=False)

# %%
# Filter dataset to 1976Q3 - 2018Q1
df_subset_final = df_subset[
    ~(df_subset['year'].astype(int) < 1976) & 
    (df_rename['quarter'] != '1976Q1') &
    (df_rename['quarter'] != '1976Q2')
#     ~(df_subset['year'].astype(int) > 2018) & 
#     (df_rename['quarter'] != '2018Q2') &
#     (df_rename['quarter'] != '2018Q3') &
#     (df_rename['quarter'] != '2018Q4')
]
df_subset_final['quarter'].sort_values()
# Out:
# /Users/gfidanli/anaconda3/envs/python3_default/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# 118    1976Q3
# 119    1976Q4
# 120    1977Q1
# 121    1977Q2
# 122    1977Q3
# 123    1977Q4
# 124    1978Q1
# 125    1978Q2
# 126    1978Q3
# 127    1978Q4
# 128    1979Q1
# 129    1979Q2
# 130    1979Q3
# 131    1979Q4
# 132    1980Q1
# 133    1980Q2
# 134    1980Q3
# 135    1980Q4
# 136    1981Q1
# 137    1981Q2
# 138    1981Q3
# 139    1981Q4
# 140    1982Q1
# 141    1982Q2
# 142    1982Q3
# 143    1982Q4
# 144    1983Q1
# 145    1983Q2
# 146    1983Q3
# 147    1983Q4
#         ...
# 260    2012Q1
# 261    2012Q2
# 262    2012Q3
# 263    2012Q4
# 264    2013Q1
# 265    2013Q2
# 266    2013Q3
# 267    2013Q4
# 268    2014Q1
# 269    2014Q2
# 270    2014Q3
# 271    2014Q4
# 272    2015Q1
# 273    2015Q2
# 274    2015Q3
# 275    2015Q4
# 276    2016Q1
# 277    2016Q2
# 278    2016Q3
# 279    2016Q4
# 280    2017Q1
# 281    2017Q2
# 282    2017Q3
# 283    2017Q4
# 284    2018Q1
# 285    2018Q2
# 286    2018Q3
# 287    2018Q4
# 288    2019Q1
# 289    2019Q2
# Name: quarter, Length: 172, dtype: object

# %%
df_subset_final.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172 entries, 118 to 289
# Data columns (total 101 columns):
# quarter                                                    172 non-null object
# real_disp_pers_inc                                         172 non-null float64
# real_disp_pers_inc_CCA                                     132 non-null float64
# real_disp_pers_inc_CCH                                     132 non-null float64
# real_disp_pers_inc_CH1                                     172 non-null float64
# real_disp_pers_inc_CHG                                     172 non-null float64
# real_disp_pers_inc_LOG                                     151 non-null float64
# real_disp_pers_inc_PC1                                     172 non-null float64
# real_disp_pers_inc_PCA                                     172 non-null float64
# real_disp_pers_inc_PCH                                     172 non-null float64
# personal_consumption_exp_excl_food_energy                  172 non-null float64
# personal_consumption_exp_excl_food_energy_CCA              172 non-null float64
# personal_consumption_exp_excl_food_energy_CCH              172 non-null float64
# personal_consumption_exp_excl_food_energy_CH1              172 non-null float64
# personal_consumption_exp_excl_food_energy_CHG              172 non-null float64
# personal_consumption_exp_excl_food_energy_LOG              172 non-null float64
# personal_consumption_exp_excl_food_energy_PC1              172 non-null float64
# personal_consumption_exp_excl_food_energy_PCA              172 non-null float64
# personal_consumption_exp_excl_food_energy_PCH              172 non-null float64
# cpi_US_total                                               172 non-null float64
# cpi_US_total_CCA                                           165 non-null float64
# cpi_US_total_CCH                                           165 non-null float64
# cpi_US_total_CH1                                           172 non-null float64
# cpi_US_total_CHG                                           172 non-null float64
# cpi_US_total_LOG                                           167 non-null float64
# cpi_US_total_PC1                                           172 non-null float64
# cpi_US_total_PCA                                           172 non-null float64
# cpi_US_total_PCH                                           172 non-null float64
# DPCERO1Q156NBEA                                            172 non-null float64
# DPCERO1Q156NBEA_CCA                                        159 non-null float64
# DPCERO1Q156NBEA_CCH                                        159 non-null float64
# DPCERO1Q156NBEA_CH1                                        172 non-null float64
# DPCERO1Q156NBEA_CHG                                        172 non-null float64
# DPCERO1Q156NBEA_LOG                                        162 non-null float64
# DPCERO1Q156NBEA_PC1                                        171 non-null float64
# DPCERO1Q156NBEA_PCA                                        171 non-null float64
# DPCERO1Q156NBEA_PCH                                        171 non-null float64
# tot_public_debt_as_pct_of_gdp                              172 non-null float64
# tot_public_debt_as_pct_of_gdp_CCA                          172 non-null float64
# tot_public_debt_as_pct_of_gdp_CCH                          172 non-null float64
# tot_public_debt_as_pct_of_gdp_CH1                          172 non-null float64
# tot_public_debt_as_pct_of_gdp_CHG                          172 non-null float64
# tot_public_debt_as_pct_of_gdp_LOG                          172 non-null float64
# tot_public_debt_as_pct_of_gdp_PC1                          172 non-null float64
# tot_public_debt_as_pct_of_gdp_PCA                          172 non-null float64
# tot_public_debt_as_pct_of_gdp_PCH                          172 non-null float64
# gross_private_domestic_invest                              172 non-null float64
# gross_private_domestic_invest_CCA                          172 non-null float64
# gross_private_domestic_invest_CCH                          172 non-null float64
# gross_private_domestic_invest_CH1                          172 non-null float64
# gross_private_domestic_invest_CHG                          172 non-null float64
# gross_private_domestic_invest_LOG                          172 non-null float64
# gross_private_domestic_invest_PC1                          172 non-null float64
# gross_private_domestic_invest_PCA                          172 non-null float64
# gross_private_domestic_invest_PCH                          172 non-null float64
# M2_velocity                                                172 non-null float64
# M2_velocity_CCA                                            172 non-null float64
# M2_velocity_CCH                                            172 non-null float64
# M2_velocity_CH1                                            172 non-null float64
# M2_velocity_CHG                                            172 non-null float64
# M2_velocity_LOG                                            172 non-null float64
# M2_velocity_PC1                                            172 non-null float64
# M2_velocity_PCA                                            172 non-null float64
# M2_velocity_PCH                                            172 non-null float64
# median_sls_price_houses_sold_US                            172 non-null float64
# median_sls_price_houses_sold_US_CCA                        172 non-null float64
# median_sls_price_houses_sold_US_CCH                        172 non-null float64
# median_sls_price_houses_sold_US_CH1                        172 non-null float64
# median_sls_price_houses_sold_US_CHG                        172 non-null float64
# median_sls_price_houses_sold_US_LOG                        172 non-null float64
# median_sls_price_houses_sold_US_PC1                        172 non-null float64
# median_sls_price_houses_sold_US_PCA                        172 non-null float64
# median_sls_price_houses_sold_US_PCH                        172 non-null float64
# nat_rate_of_unemp_long_term                                172 non-null float64
# nat_rate_of_unemp_long_term_CCA                            172 non-null float64
# nat_rate_of_unemp_long_term_CCH                            172 non-null float64
# nat_rate_of_unemp_long_term_CH1                            172 non-null float64
# nat_rate_of_unemp_long_term_CHG                            172 non-null float64
# nat_rate_of_unemp_long_term_LOG                            172 non-null float64
# nat_rate_of_unemp_long_term_PC1                            172 non-null float64
# nat_rate_of_unemp_long_term_PCA                            172 non-null float64
# nat_rate_of_unemp_long_term_PCH                            172 non-null float64
# personal_consumption_expenditures                          172 non-null float64
# personal_consumption_expenditures_CCA                      172 non-null float64
# personal_consumption_expenditures_CCH                      172 non-null float64
# personal_consumption_expenditures_CH1                      172 non-null float64
# personal_consumption_expenditures_CHG                      172 non-null float64
# personal_consumption_expenditures_LOG                      172 non-null float64
# personal_consumption_expenditures_PC1                      172 non-null float64
# personal_consumption_expenditures_PCA                      172 non-null float64
# personal_consumption_expenditures_PCH                      172 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income        158 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CCA    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CCH    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CH1    154 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_CHG    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_LOG    158 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PC1    154 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PCA    157 non-null float64
# hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH    157 non-null float64
# year                                                       172 non-null object
# dtypes: float64(99), object(2)
# memory usage: 137.1+ KB

# %%
# Columns with high numbe rof missing
cols_to_drop= [
    'hh_debt_service_pmts_as_pct_of_disp_personal_income',
    'hh_debt_service_pmts_as_pct_of_disp_personal_income_CCA',
    'hh_debt_service_pmts_as_pct_of_disp_personal_income_CCH',
    'hh_debt_service_pmts_as_pct_of_disp_personal_income_CH1',
    'hh_debt_service_pmts_as_pct_of_disp_personal_income_CHG',
    'hh_debt_service_pmts_as_pct_of_disp_personal_income_LOG',
    'hh_debt_service_pmts_as_pct_of_disp_personal_income_PC1',
    'hh_debt_service_pmts_as_pct_of_disp_personal_income_PCA',
    'hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH'
]
df_subset_final = df_subset_final.drop(columns=cols_to_drop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-1c96e3997bba> in <module>
#      11     'hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH'
#      12 ]
# ---> 13 df_subset_final = df_subset_final.drop(columns=cols_to_drop)
#
# ~/anaconda3/envs/python3_default/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/envs/python3_default/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~/anaconda3/envs/python3_default/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# ~/anaconda3/envs/python3_default/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['hh_debt_service_pmts_as_pct_of_disp_personal_income'\n 'hh_debt_service_pmts_as_pct_of_disp_personal_income_CCA'\n 'hh_debt_service_pmts_as_pct_of_disp_personal_income_CCH'\n 'hh_debt_service_pmts_as_pct_of_disp_personal_income_CH1'\n 'hh_debt_service_pmts_as_pct_of_disp_personal_income_CHG'\n 'hh_debt_service_pmts_as_pct_of_disp_personal_income_LOG'\n 'hh_debt_service_pmts_as_pct_of_disp_personal_income_PC1'\n 'hh_debt_service_pmts_as_pct_of_disp_personal_income_PCA'\n 'hh_debt_service_pmts_as_pct_of_disp_personal_income_PCH'] not found in axis"

# %%
cols_to_remove = ['DPCERO1Q156NBEA_LOG',
'real_disp_pers_inc_CCA',
'real_disp_pers_inc_CCH',
'real_disp_pers_inc_LOG',
'cpi_US_total_CCA',
'cpi_US_total_CCH',
'cpi_US_total_LOG',
'DPCERO1Q156NBEA_CCA',
'DPCERO1Q156NBEA_CCH',
'DPCERO1Q156NBEA_LOG',
'DPCERO1Q156NBEA_PC1',
'DPCERO1Q156NBEA_PCA',
'DPCERO1Q156NBEA_PCH']

df_subset_final = df_subset_final.drop(columns=cols_to_remove)

df_subset_final.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172 entries, 118 to 289
# Data columns (total 80 columns):
# quarter                                          172 non-null object
# real_disp_pers_inc                               172 non-null float64
# real_disp_pers_inc_CH1                           172 non-null float64
# real_disp_pers_inc_CHG                           172 non-null float64
# real_disp_pers_inc_PC1                           172 non-null float64
# real_disp_pers_inc_PCA                           172 non-null float64
# real_disp_pers_inc_PCH                           172 non-null float64
# personal_consumption_exp_excl_food_energy        172 non-null float64
# personal_consumption_exp_excl_food_energy_CCA    172 non-null float64
# personal_consumption_exp_excl_food_energy_CCH    172 non-null float64
# personal_consumption_exp_excl_food_energy_CH1    172 non-null float64
# personal_consumption_exp_excl_food_energy_CHG    172 non-null float64
# personal_consumption_exp_excl_food_energy_LOG    172 non-null float64
# personal_consumption_exp_excl_food_energy_PC1    172 non-null float64
# personal_consumption_exp_excl_food_energy_PCA    172 non-null float64
# personal_consumption_exp_excl_food_energy_PCH    172 non-null float64
# cpi_US_total                                     172 non-null float64
# cpi_US_total_CH1                                 172 non-null float64
# cpi_US_total_CHG                                 172 non-null float64
# cpi_US_total_PC1                                 172 non-null float64
# cpi_US_total_PCA                                 172 non-null float64
# cpi_US_total_PCH                                 172 non-null float64
# DPCERO1Q156NBEA                                  172 non-null float64
# DPCERO1Q156NBEA_CH1                              172 non-null float64
# DPCERO1Q156NBEA_CHG                              172 non-null float64
# tot_public_debt_as_pct_of_gdp                    172 non-null float64
# tot_public_debt_as_pct_of_gdp_CCA                172 non-null float64
# tot_public_debt_as_pct_of_gdp_CCH                172 non-null float64
# tot_public_debt_as_pct_of_gdp_CH1                172 non-null float64
# tot_public_debt_as_pct_of_gdp_CHG                172 non-null float64
# tot_public_debt_as_pct_of_gdp_LOG                172 non-null float64
# tot_public_debt_as_pct_of_gdp_PC1                172 non-null float64
# tot_public_debt_as_pct_of_gdp_PCA                172 non-null float64
# tot_public_debt_as_pct_of_gdp_PCH                172 non-null float64
# gross_private_domestic_invest                    172 non-null float64
# gross_private_domestic_invest_CCA                172 non-null float64
# gross_private_domestic_invest_CCH                172 non-null float64
# gross_private_domestic_invest_CH1                172 non-null float64
# gross_private_domestic_invest_CHG                172 non-null float64
# gross_private_domestic_invest_LOG                172 non-null float64
# gross_private_domestic_invest_PC1                172 non-null float64
# gross_private_domestic_invest_PCA                172 non-null float64
# gross_private_domestic_invest_PCH                172 non-null float64
# M2_velocity                                      172 non-null float64
# M2_velocity_CCA                                  172 non-null float64
# M2_velocity_CCH                                  172 non-null float64
# M2_velocity_CH1                                  172 non-null float64
# M2_velocity_CHG                                  172 non-null float64
# M2_velocity_LOG                                  172 non-null float64
# M2_velocity_PC1                                  172 non-null float64
# M2_velocity_PCA                                  172 non-null float64
# M2_velocity_PCH                                  172 non-null float64
# median_sls_price_houses_sold_US                  172 non-null float64
# median_sls_price_houses_sold_US_CCA              172 non-null float64
# median_sls_price_houses_sold_US_CCH              172 non-null float64
# median_sls_price_houses_sold_US_CH1              172 non-null float64
# median_sls_price_houses_sold_US_CHG              172 non-null float64
# median_sls_price_houses_sold_US_LOG              172 non-null float64
# median_sls_price_houses_sold_US_PC1              172 non-null float64
# median_sls_price_houses_sold_US_PCA              172 non-null float64
# median_sls_price_houses_sold_US_PCH              172 non-null float64
# nat_rate_of_unemp_long_term                      172 non-null float64
# nat_rate_of_unemp_long_term_CCA                  172 non-null float64
# nat_rate_of_unemp_long_term_CCH                  172 non-null float64
# nat_rate_of_unemp_long_term_CH1                  172 non-null float64
# nat_rate_of_unemp_long_term_CHG                  172 non-null float64
# nat_rate_of_unemp_long_term_LOG                  172 non-null float64
# nat_rate_of_unemp_long_term_PC1                  172 non-null float64
# nat_rate_of_unemp_long_term_PCA                  172 non-null float64
# nat_rate_of_unemp_long_term_PCH                  172 non-null float64
# personal_consumption_expenditures                172 non-null float64
# personal_consumption_expenditures_CCA            172 non-null float64
# personal_consumption_expenditures_CCH            172 non-null float64
# personal_consumption_expenditures_CH1            172 non-null float64
# personal_consumption_expenditures_CHG            172 non-null float64
# personal_consumption_expenditures_LOG            172 non-null float64
# personal_consumption_expenditures_PC1            172 non-null float64
# personal_consumption_expenditures_PCA            172 non-null float64
# personal_consumption_expenditures_PCH            172 non-null float64
# year                                             172 non-null object
# dtypes: float64(78), object(2)
# memory usage: 108.8+ KB

# %%
df_subset_final.to_csv('../resources/FRED_data.csv', index=False)
